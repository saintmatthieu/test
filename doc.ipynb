# %% [markdown]
# # My notebook

# %%
from matplotlib import pyplot as plt
plt.plot([0, 1])
plt.show()

# %% [markdown]
# $\begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}$
